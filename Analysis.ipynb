# %%
import numpy as np
import pandas as pd

# NumPy array
arr = np.array([1, 2, 3, 4, 5])
print(arr)

# Pandas DataFrame
data = {
    "Name": ["Pranay", "Rahul", "Aman"],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)

print(df)
# Out:
# [1 2 3 4 5]
#      Name  Marks
# 0  Pranay     85
# 1   Rahul     90
# 2    Aman     78
